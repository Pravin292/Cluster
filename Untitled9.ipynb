# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df= pd.read_csv('Mall_Customers.csv')
df= df.drop('CustomerID',axis=1)
df.head()
# Out:
#     Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
x = df[['Annual Income (k$)','Spending Score (1-100)']]

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)

print("WCSS values:",wcss)

plt.plot(range(1,11),wcss,marker='o',linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()
# Out:
# WCSS values: [399.99999999999994, 269.69101219276405, 157.70400815035939, 108.92131661364358, 65.56840815571681, 55.057348270385965, 44.86475569922555, 37.22818767758587, 32.39226763033118, 29.981897788243703]

# %%
kmeans = KMeans(n_clusters =5,random_state=42)
df['Cluster'] = kmeans.fit_predict(x_scaled)
df.head(10)
# Out:
#     Genre  Age  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0    Male   19                  15                      39        4
# 1    Male   21                  15                      81        2
# 2  Female   20                  16                       6        4
# 3  Female   23                  16                      77        2
# 4  Female   31                  17                      40        4
# 5  Female   22                  17                      76        2
# 6  Female   35                  18                       6        4
# 7  Female   23                  18                      94        2
# 8    Male   64                  19                       3        4
# 9  Female   30                  19                      72        2

# %%
df
# Out:
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0      Male   19                  15                      39        4
# 1      Male   21                  15                      81        2
# 2    Female   20                  16                       6        4
# 3    Female   23                  16                      77        2
# 4    Female   31                  17                      40        4
# ..      ...  ...                 ...                     ...      ...
# 195  Female   35                 120                      79        1
# 196  Female   45                 126                      28        3
# 197    Male   32                 126                      74        1
# 198    Male   32                 137                      18        3
# 199    Male   30                 137                      83        1
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(8,6))
for cluster in range(5):
  plt.scatter(
  df[df['Cluster']== cluster]["Annual Income (k$)"],
  df[df['Cluster']== cluster]["Spending Score (1-100)"],
  label=f'Cluster {cluster}'
  )


  plt.xlabel('Annual Income (k$)')
  plt.ylabel('Spending Score (1-100)')
  plt.title('Customer Segments')
  plt.legend()

# %%
import joblib

joblib.dump(scaler,"scaler.pxl")
joblib.dump(kmeans,"kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']
